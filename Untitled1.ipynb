# %%
import json
import pprint
import requests
import pandas as pd
from bs4 import BeautifulSoup

from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark import SparkContext

spark = SparkSession.builder.appName('pubg').getOrCreate()

# %%
user = "txQQ-2158195697"
url = "https://pubg.op.gg/user/" + user
result = requests.get(url)

# Extract data-user_id from opgg
soup = BeautifulSoup(result.text, 'html.parser')
player_summary = soup.find("div", {"class": "player-summary__name"})
data_user_id = player_summary.get('data-user_id')
print(data_user_id)
# Out:
# 5f6396be4f6ca80001afec03

# %%
# Navigate to proper URL and save to df
url = f'https://pubg.op.gg/api/users/{data_user_id}/matches/recent'
result = requests.get(url)
soup = BeautifulSoup(result.text, 'html.parser')
soup_json=json.loads(soup.text)

# %%
sc = SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

columns = ['id', 'dogs', 'cats']
vals = [(1, 2, 0), (2, 0, 1)]

df = spark.createDataFrame(vals, columns)

newRow = spark.createDataFrame([(4,5,7)], columns)
appended = df.union(newRow)
appended.show()
# Out:
# +---+----+----+
# | id|dogs|cats|
# +---+----+----+
# |  1|   2|   0|
# |  2|   0|   1|
# |  4|   5|   7|
# +---+----+----+

# %%
game_num = 0

# %%
for i in range(20):
    game_num = i
    # type
    print(soup_json['matches']['items'][game_num]['type'])
    # mode
    print(soup_json['matches']['items'][game_num]['mode'])
    # started_at
    print(soup_json['matches']['items'][game_num]['started_at'])
    # total_rank
    print(soup_json['matches']['items'][game_num]['total_rank'])
    # queue_size
    print(soup_json['matches']['items'][game_num]['queue_size'])
    # map_name
    print(soup_json['matches']['items'][game_num]['map_name'])
    # match_type
    print(soup_json['matches']['items'][game_num]['match_type'])
    # queue_size
    print(soup_json['matches']['items'][game_num]['queue_size'])
    # nickname
    print(soup_json['matches']['items'][game_num]['participant']['user']['nickname'])
    # rank
    print(soup_json['matches']['items'][game_num]['participant']['stats']['rank'])
    # heals
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['heals'])
    # boosts
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['boosts'])
    # death_type
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['death_type'])
    # time_survived
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['time_survived'])
    # kills
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kills'])
    # assists
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['assists'])
    # kill_steaks
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kill_steaks'])
    # headshot_kills
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['headshot_kills'])
    # longest_kill
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['longest_kill'])
    # kills
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kills'])
    # damage_dealt
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['damage']['damage_dealt'])
    # knock_downs
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['dbno']['knock_downs'])
    # revives
    print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['dbno']['revives'])
# Out:
# official
# fpp
# 2021-05-13T22:03:51+0000
# 17
# 4
# Baltic_Main
# competitive
# 4
# txQQ-2158195697
# 1
# 1
# 10
# alive
# 1474.5589599609375
# 7
# 3
# 3
# 4
# 193.01730346679688
# 7
# 1314
# 6
# 2
# official
# fpp
# 2021-05-13T21:32:38+0000
# 16
# 4
# Desert_Main
# competitive
# 4
# txQQ-2158195697
# 1
# 6
# 22
# alive
# 1648.39697265625
# 10
# 1
# 4
# 5
# 211.59112548828125
# 10
# 1364
# 11
# 0
# official
# fpp
# 2021-05-13T20:57:44+0000
# 17
# 4
# Desert_Main
# competitive
# 4
# txQQ-2158195697
# 2
# 0
# 12
# byplayer
# 1858.9530029296875
# 6
# 1
# 1
# 4
# 280.5963134765625
# 6
# 951
# 8
# 0
# official
# fpp
# 2021-05-13T20:28:31+0000
# 16
# 4
# Desert_Main
# competitive
# 4
# txQQ-2158195697
# 1
# 3
# 19
# alive
# 1563.427001953125
# 5
# 3
# 1
# 4
# 121.4177017211914
# 5
# 1029
# 6
# 2
# official
# tpp
# 2021-05-13T13:03:39+0000
# 17
# 4
# Chimera_Main
# official
# 4
# txQQ-2158195697
# 4
# 7
# 12
# byplayer
# 1046.0009765625
# 3
# 3
# 2
# 1
# 18.45926856994629
# 3
# 777
# 5
# ...

# %%
# type
print(soup_json['matches']['items'][game_num]['type'])
# mode
print(soup_json['matches']['items'][game_num]['mode'])
# started_at
print(soup_json['matches']['items'][game_num]['started_at'])
# total_rank
print(soup_json['matches']['items'][game_num]['total_rank'])
# queue_size
print(soup_json['matches']['items'][game_num]['queue_size'])
# map_name
print(soup_json['matches']['items'][game_num]['map_name'])
# match_type
print(soup_json['matches']['items'][game_num]['match_type'])
# queue_size
print(soup_json['matches']['items'][game_num]['queue_size'])
# nickname
print(soup_json['matches']['items'][game_num]['participant']['user']['nickname'])
# rank
print(soup_json['matches']['items'][game_num]['participant']['stats']['rank'])
# heals
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['heals'])
# boosts
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['boosts'])
# death_type
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['death_type'])
# time_survived
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['time_survived'])
# kills
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kills'])
# assists
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['assists'])
# kill_steaks
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kill_steaks'])
# headshot_kills
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['headshot_kills'])
# longest_kill
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['longest_kill'])
# kills
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['kda']['kills'])
# damage_dealt
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['damage']['damage_dealt'])
# knock_downs
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['dbno']['knock_downs'])
# revives
print(soup_json['matches']['items'][game_num]['participant']['stats']['combat']['dbno']['revives'])
# Out:
# official
# fpp
# 2021-05-13T22:03:51+0000
# 17
# 4
# Baltic_Main
# competitive
# 4
# txQQ-2158195697
# 1
# 1
# 10
# alive
# 1474.5589599609375
# 7
# 3
# 3
# 4
# 193.01730346679688
# 7
# 1314
# 6
# 2

# %%
from pyspark import SparkContext                                                                                                                                 
import os

def test_whatever():
    os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages graphframes:graphframes:0.5.0-spark2.1-s_2.11,com.databricks:spark-avro_2.11:3.2.0 pyspark-shell'
    sc = SparkContext.getOrCreate()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('pubg').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-ab6fcf154b96> in <module>
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName('pubg').getOrCreate()
#
# ~/.local/lib/python3.8/site-packages/pyspark/sql/session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# ~/.local/lib/python3.8/site-packages/pyspark/context.py in getOrCreate(cls, conf)
#     382         with SparkContext._lock:
#     383             if SparkContext._active_spark_context is None:
# ...

# %%
# Continue to get next data page using "offset" value
